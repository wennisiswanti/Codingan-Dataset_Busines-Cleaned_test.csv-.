# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cleaned_df = pd.read_csv('cleaned_test.csv')

# %%
cleaned = pd.read_csv('cleaned_test.csv')

# %% [markdown]
# # 1. menampilkan data set sesuai dengan format dari cleaned_test.csv

# %%
cleaned
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# 4                          4.6            12.986047             80.218114
# ...                        ...                  ...                   ...
# 11394                      4.6            26.905190             75.810753
# 11395                      4.9            26.902940             75.793007
# 11396                      NaN            21.157735             72.768778
# 11397                      4.7            22.320000             73.170000
# 11398                      5.0            13.081878             80.248519
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 0                       11.043669                    77.016494  30-03-2022
# 1                       13.085377                    77.806664  29-03-2022
# 2                       27.001378                    75.879034  10-03-2022
# 3                       26.856536                    75.927333  02-04-2022
# 4                       13.096047                    80.328114  27-03-2022
# ...                           ...                          ...         ...
# 11394                   27.015190                    75.920753  27-03-2022
# 11395                   26.912940                    75.803007  11-03-2022
# 11396                   21.217735                    72.828778  11-03-2022
# 11397                   22.450000                    73.300000  06-03-2022
# 11398                   13.131878                    80.298519  24-03-2022
#
#       Time_Orderd Time_Order_picked     Weather Road_traffic_density  \
# 0             NaN             15:05         NaN                  NaN
# 1           20:30             20:35       Windy                  Jam
# 2           19:35             19:45      Stormy                  Jam
# 3           17:15             17:20         Fog               Medium
# 4           18:25             18:40       Sunny               Medium
# ...           ...               ...         ...                  ...
# 11394       21:35             21:45       Sunny                  Jam
# 11395       11:40             11:45  Sandstorms                 High
# 11396         NaN             21:05         NaN                  NaN
# 11397       18:35             18:40  Sandstorms               Medium
# 11398       22:20             22:25       Windy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries  \
# 0                      3        Drinks  electric_scooter                  1.0
# 1                      0         Snack        motorcycle                  1.0
# 2                      0        Drinks        motorcycle                  1.0
# 3                      1          Meal           scooter                  1.0
# 4                      2        Drinks           scooter                  1.0
# ...                  ...           ...               ...                  ...
# 11394                  1         Snack           scooter                  1.0
# 11395                  1        Drinks           scooter                  1.0
# 11396                  3        Drinks           scooter                  1.0
# 11397                  0          Meal        motorcycle                  0.0
# 11398                  2        Drinks        motorcycle                  1.0
#
#       Festival           City   Name:
# 0           No  Metropolitian  object
# 1           No  Metropolitian  object
# 2           No  Metropolitian  object
# 3           No  Metropolitian  object
# 4           No  Metropolitian  object
# ...        ...            ...     ...
# 11394       No  Metropolitian  object
# 11395       No  Metropolitian  object
# 11396       No  Metropolitian  object
# 11397       No  Metropolitian  object
# 11398       No          Urban  object
#
# [11399 rows x 20 columns]

# %% [markdown]
# # 2. menampilkan kolom

# %%
cleaned.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Name:'],
#       dtype='object')

# %% [markdown]
# # 3. menampilkan jumlah baris dan jumlah kolom dari dataset

# %%
cleaned.shape
# Out:
# (11399, 20)

# %%
print ("Jumlah Baris:",cleaned.shape[0])
print ("Jumlah Kolom:",cleaned.shape[1])
# Out:
# Jumlah Baris: 11399
# Jumlah Kolom: 20

# %% [markdown]
# # 4. menampilkan informasi tentang dataset seperti jumlah total baris, jumlah total kolom, tipe data dari setiap kolom dan kebutuhan memori

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11399 entries, 0 to 11398
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           11399 non-null  object
#  1   Delivery_person_ID           11399 non-null  object
#  2   Delivery_person_Age          10908 non-null  float64
#  3   Delivery_person_Ratings      10892 non-null  float64
#  4   Restaurant_latitude          11399 non-null  float64
#  5   Restaurant_longitude         11399 non-null  float64
#  6   Delivery_location_latitude   11399 non-null  float64
#  7   Delivery_location_longitude  11399 non-null  float64
#  8   Order_Date                   11399 non-null  object
#  9   Time_Orderd                  10955 non-null  object
#  10  Time_Order_picked            11399 non-null  object
#  11  Weather                      11241 non-null  object
#  12  Road_traffic_density         11245 non-null  object
#  13  Vehicle_condition            11399 non-null  int64
#  14  Type_of_order                11399 non-null  object
#  15  Type_of_vehicle              11399 non-null  object
#  16  multiple_deliveries          11161 non-null  float64
#  17  Festival                     11334 non-null  object
#  18  City                         11075 non-null  object
#  19  Name:                        11399 non-null  object
# dtypes: float64(7), int64(1), object(12)
# memory usage: 1.7+ MB

# %% [markdown]
# # 5. menampilkan tipe data

# %%
cleaned.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather                         object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Name:                           object
# dtype: object

# %% [markdown]
# # 6. Menampilkan seluruh Dataset

# %%
print(df)
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# 4                          4.6            12.986047             80.218114
# ...                        ...                  ...                   ...
# 11394                      4.6            26.905190             75.810753
# 11395                      4.9            26.902940             75.793007
# 11396                      NaN            21.157735             72.768778
# 11397                      4.7            22.320000             73.170000
# 11398                      5.0            13.081878             80.248519
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 0                       11.043669                    77.016494  30-03-2022
# 1                       13.085377                    77.806664  29-03-2022
# 2                       27.001378                    75.879034  10-03-2022
# 3                       26.856536                    75.927333  02-04-2022
# 4                       13.096047                    80.328114  27-03-2022
# ...                           ...                          ...         ...
# 11394                   27.015190                    75.920753  27-03-2022
# 11395                   26.912940                    75.803007  11-03-2022
# 11396                   21.217735                    72.828778  11-03-2022
# 11397                   22.450000                    73.300000  06-03-2022
# 11398                   13.131878                    80.298519  24-03-2022
#
#       Time_Orderd Time_Order_picked     Weather Road_traffic_density  \
# 0             NaN             15:05         NaN                  NaN
# 1           20:30             20:35       Windy                  Jam
# 2           19:35             19:45      Stormy                  Jam
# 3           17:15             17:20         Fog               Medium
# 4           18:25             18:40       Sunny               Medium
# ...           ...               ...         ...                  ...
# 11394       21:35             21:45       Sunny                  Jam
# 11395       11:40             11:45  Sandstorms                 High
# 11396         NaN             21:05         NaN                  NaN
# 11397       18:35             18:40  Sandstorms               Medium
# 11398       22:20             22:25       Windy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries  \
# 0                      3        Drinks  electric_scooter                  1.0
# 1                      0         Snack        motorcycle                  1.0
# 2                      0        Drinks        motorcycle                  1.0
# 3                      1          Meal           scooter                  1.0
# 4                      2        Drinks           scooter                  1.0
# ...                  ...           ...               ...                  ...
# 11394                  1         Snack           scooter                  1.0
# 11395                  1        Drinks           scooter                  1.0
# 11396                  3        Drinks           scooter                  1.0
# 11397                  0          Meal        motorcycle                  0.0
# 11398                  2        Drinks        motorcycle                  1.0
#
#       Festival           City   Name:
# 0           No  Metropolitian  object
# 1           No  Metropolitian  object
# 2           No  Metropolitian  object
# 3           No  Metropolitian  object
# 4           No  Metropolitian  object
# ...        ...            ...     ...
# 11394       No  Metropolitian  object
# 11395       No  Metropolitian  object
# 11396       No  Metropolitian  object
# 11397       No  Metropolitian  object
# 11398       No          Urban  object
#
# [11399 rows x 20 columns]

# %% [markdown]
# # 7. membagi dataset

# %%
x = cleaned.iloc[:,:-1]. values
y = cleaned.iloc[:,-1].values

print (x)
# Out:
# [['0x2318' 'COIMBRES13DEL01' nan ... 1.0 'No' 'Metropolitian']
#  ['0x3474' 'BANGRES15DEL01' 28.0 ... 1.0 'No' 'Metropolitian']
#  ['0x9420' 'JAPRES09DEL03' 23.0 ... 1.0 'No' 'Metropolitian']
#  ...
#  ['0x1ea5' 'SURRES11DEL03' nan ... 1.0 'No' 'Metropolitian']
#  ['0x22d4' 'VADRES03DEL02' 27.0 ... 0.0 'No' 'Metropolitian']
#  ['0xb7be' 'CHENRES07DEL02' 39.0 ... 1.0 'No' 'Urban']]

# %% [markdown]
# # 8. menampilkan 20 data pertama cleaned.head(20)

# %%
cleaned.head(20)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0   0x2318    COIMBRES13DEL01                  NaN                      NaN
# 1   0x3474     BANGRES15DEL01                 28.0                      4.6
# 2   0x9420      JAPRES09DEL03                 23.0                      4.5
# 3   0x72ee      JAPRES07DEL03                 21.0                      4.8
# 4   0xa759     CHENRES19DEL01                 31.0                      4.6
# 5   0xc4af      GOARES04DEL01                 26.0                      4.7
# 6   0x3b9d     BANGRES19DEL02                 23.0                      4.8
# 7   0xdd42      KOLRES06DEL02                 26.0                      4.8
# 8   0x872b      MYSRES05DEL03                 35.0                      4.9
# 9   0x6001      HYDRES04DEL03                 23.0                      4.9
# 10  0xd845      KOCRES09DEL01                 24.0                      4.8
# 11  0x4946      VADRES04DEL01                 22.0                      4.6
# 12  0x4598   RANCHIRES14DEL03                 35.0                      4.8
# 13  0xbd51     BANGRES11DEL01                 33.0                      4.8
# 14  0x73ec  RANCHIRES010DEL03                 36.0                      4.6
# 15  0x5ca7      HYDRES19DEL03                 34.0                      4.6
# 16  0x9fa6    COIMBRES03DEL03                 38.0                      4.2
# 17  0x914e      HYDRES12DEL02                 34.0                      4.6
# 18  0x36e5     CHENRES20DEL03                 37.0                      4.7
# 19  0xd82e      KOCRES09DEL02                 21.0                      4.5
#
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0             11.003669             76.976494                   11.043669
# 1             12.975377             77.696664                   13.085377
# 2             26.911378             75.789034                   27.001378
# 3             26.766536             75.837333                   26.856536
# 4             12.986047             80.218114                   13.096047
# 5             15.569600             73.742294                   15.579600
# 6             12.914264             77.678400                   12.934264
# 7             22.533662             88.366217                   22.583662
# 8             12.323978             76.627961                   12.413978
# 9             17.411028             78.329645                   17.441028
# 10            10.000706             76.349516                   10.040706
# 11             0.000000              0.000000                    0.110000
# 12             0.000000              0.000000                    0.060000
# 13            12.934365             77.616155                   13.044365
# 14            23.354422             85.332900                   23.414422
# 15            17.458998             78.500366                   17.488998
# 16            11.025083             77.015393                   11.055083
# 17            17.429585             78.392621                   17.559585
# 18            12.975996             80.221898                   13.005996
# 19            10.000706             76.349516                   10.130706
#
#     Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                     77.016494  30-03-2022         NaN             15:05
# 1                     77.806664  29-03-2022       20:30             20:35
# 2                     75.879034  10-03-2022       19:35             19:45
# 3                     75.927333  02-04-2022       17:15             17:20
# 4                     80.328114  27-03-2022       18:25             18:40
# 5                     73.752294  15-02-2022        9:45              9:55
# 6                     77.698400  01-04-2022        9:60             10:05
# 7                     88.416217  13-02-2022       17:60             18:05
# 8                     76.717961  02-03-2022       21:30             21:45
# 9                     78.359645  05-04-2022       20:45             20:55
# 10                    76.389516  17-02-2022       14:35             14:40
# 11                     0.110000  08-03-2022       23:40             23:50
# 12                     0.060000  01-04-2022       22:15             22:25
# 13                    77.726155  16-03-2022       23:40             23:55
# 14                    85.392900  17-03-2022       21:30             21:40
# 15                    78.530366  01-04-2022       20:35             20:50
# 16                    77.045393  15-03-2022       20:30             20:35
# 17                    78.522621  14-03-2022       21:55             22:10
# 18                    80.251898  24-03-2022       18:35             18:50
# 19                    76.479516  16-02-2022       21:20             21:25
#
#    Weather Road_traffic_density  Vehicle_condition Type_of_order  \
# 0      NaN                  NaN                  3        Drinks
# 1    Windy                  Jam                  0         Snack
# 2   Stormy                  Jam                  0        Drinks
# 3      Fog               Medium                  1          Meal
# 4    Sunny               Medium                  2        Drinks
# 5      Fog                  Low                  0        Drinks
# 6    Windy                  Low                  2        Buffet
# 7    Windy               Medium                  0          Meal
# 8   Cloudy                  Jam                  2         Snack
# 9      Fog                  Jam                  1          Meal
# 10  Stormy                 High                  2         Snack
# 11   Windy                  Low                  1        Drinks
# 12   Sunny                  Low                  2         Snack
# 13   Windy                  Low                  2        Drinks
# 14     Fog                  Jam                  1          Meal
# 15  Cloudy                  Jam                  2         Snack
# 16   Windy                  Jam                  2        Buffet
# 17   Sunny                  Jam                  2         Snack
# 18  Cloudy               Medium                  2         Snack
# 19  Stormy                  Jam                  1        Drinks
#
#      Type_of_vehicle  multiple_deliveries Festival           City   Name:
# 0   electric_scooter                  1.0       No  Metropolitian  object
# 1         motorcycle                  1.0       No  Metropolitian  object
# 2         motorcycle                  1.0       No  Metropolitian  object
# 3            scooter                  1.0       No  Metropolitian  object
# 4            scooter                  1.0       No  Metropolitian  object
# 5         motorcycle                  1.0       No  Metropolitian  object
# 6            scooter                  0.0       No          Urban  object
# 7         motorcycle                  1.0       No  Metropolitian  object
# 8            scooter                  1.0       No  Metropolitian  object
# 9         motorcycle                  0.0       No  Metropolitian  object
# 10        motorcycle                  1.0       No  Metropolitian  object
# 11           scooter                  NaN       No          Urban  object
# 12           scooter                  0.0       No  Metropolitian  object
# 13  electric_scooter                  0.0       No          Urban  object
# 14           scooter                  0.0       No  Metropolitian  object
# 15  electric_scooter                  0.0       No  Metropolitian  object
# 16        motorcycle                  1.0       No  Metropolitian  object
# 17           scooter                  0.0       No  Metropolitian  object
# 18           scooter                  0.0       No  Metropolitian  object
# 19           scooter                  1.0       No          Urban  object

# %% [markdown]
# # 9. menampilkan 10 data terakhir

# %%
cleaned.tail(10)
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 11389  0x7169      VADRES14DEL03                 28.0
# 11390  0x77aa     INDORES06DEL03                 31.0
# 11391  0xd3de     LUDHRES07DEL03                 26.0
# 11392  0x116c     PUNERES04DEL03                  NaN
# 11393  0xe240      BHPRES07DEL01                 31.0
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 11389                      4.9            22.311603             73.165012
# 11390                      5.0            22.728163             75.884212
# 11391                      4.8             0.000000              0.000000
# 11392                      NaN            18.514210             73.838429
# 11393                      4.7             0.000000              0.000000
# 11394                      4.6            26.905190             75.810753
# 11395                      4.9            26.902940             75.793007
# 11396                      NaN            21.157735             72.768778
# 11397                      4.7            22.320000             73.170000
# 11398                      5.0            13.081878             80.248519
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 11389                   22.401603                    73.255012  02-04-2022
# 11390                   22.818163                    75.974212  12-03-2022
# 11391                    0.060000                     0.060000  15-02-2022
# 11392                   18.544210                    73.868429  07-03-2022
# 11393                    0.010000                     0.010000  13-02-2022
# 11394                   27.015190                    75.920753  27-03-2022
# 11395                   26.912940                    75.803007  11-03-2022
# 11396                   21.217735                    72.828778  11-03-2022
# 11397                   22.450000                    73.300000  06-03-2022
# 11398                   13.131878                    80.298519  24-03-2022
#
#       Time_Orderd Time_Order_picked     Weather Road_traffic_density  \
# 11389       21:45             21:60         Fog                  Jam
# 11390       22:35             22:50         Fog                  Low
# 11391       23:10             23:20      Cloudy                  Low
# 11392       17:25             17:40      Cloudy               Medium
# 11393       10:60             11:10       Windy                  Low
# 11394       21:35             21:45       Sunny                  Jam
# 11395       11:40             11:45  Sandstorms                 High
# 11396         NaN             21:05         NaN                  NaN
# 11397       18:35             18:40  Sandstorms               Medium
# 11398       22:20             22:25       Windy                  Low
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 11389                  0         Snack      motorcycle                  2.0
# 11390                  0          Meal      motorcycle                  1.0
# 11391                  0        Drinks      motorcycle                  0.0
# 11392                  0          Meal      motorcycle                  0.0
# 11393                  2         Snack         scooter                  1.0
# 11394                  1         Snack         scooter                  1.0
# 11395                  1        Drinks         scooter                  1.0
# 11396                  3        Drinks         scooter                  1.0
# 11397                  0          Meal      motorcycle                  0.0
# 11398                  2        Drinks      motorcycle                  1.0
#
#       Festival           City   Name:
# 11389       No  Metropolitian  object
# 11390       No  Metropolitian  object
# 11391       No          Urban  object
# 11392       No  Metropolitian  object
# 11393       No  Metropolitian  object
# 11394       No  Metropolitian  object
# 11395       No  Metropolitian  object
# 11396       No  Metropolitian  object
# 11397       No  Metropolitian  object
# 11398       No          Urban  object

# %% [markdown]
# # 10. menampilakan macam-macam type of order

# %%
cleaned_Type_of_order = list(cleaned['Type_of_order'].unique())
cleaned_Type_of_order.sort()
cleaned_Type_of_order
# Out:
# ['Buffet', 'Drinks', 'Meal', 'Snack']

# %% [markdown]
# #11.  menampilkan berapa kali weather muncul

# %%
cleaned['Weather'].value_counts()
# Out:
# Sunny         1975
# Windy         1948
# Sandstorms    1878
# Cloudy        1861
# Stormy        1811
# Fog           1768
# Name: Weather, dtype: int64

# %% [markdown]
# # 12. memvisualisasikan jumlah rating

# %%
plt.figure(figsize=(8,5))
sns.countplot (x='Road_traffic_density',data=cleaned)
# Out:
# <Axes: xlabel='Road_traffic_density', ylabel='count'>

# %% [markdown]
# # 13. menampilkan dan menghitung jumlah Vehicle condition 1

# %%
df = pd.read_csv('cleaned_test.csv')
Vehicle_condition_1 = df[df['Vehicle_condition'] == 1]
print("Jumlah msft rating 4:",len(Vehicle_condition_1))

cleaned_Vehicle_condition1 = cleaned_df[(cleaned_df['Vehicle_condition'] == 1)]
cleaned_Vehicle_condition1.head(10)
# Out:
# Jumlah msft rating 4: 3734
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 3   0x72ee      JAPRES07DEL03                 21.0                      4.8
# 9   0x6001      HYDRES04DEL03                 23.0                      4.9
# 11  0x4946      VADRES04DEL01                 22.0                      4.6
# 14  0x73ec  RANCHIRES010DEL03                 36.0                      4.6
# 19  0xd82e      KOCRES09DEL02                 21.0                      4.5
# 20  0x1df3      JAPRES20DEL03                 28.0                      2.7
# 30  0x4b7e    COIMBRES17DEL02                 20.0                      5.0
# 32  0x368e      SURRES11DEL02                 23.0                      4.7
# 33   0xe09     CHENRES08DEL03                 29.0                      4.7
# 36  0x7604      JAPRES02DEL02                 20.0                      4.6
#
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 3             26.766536             75.837333                   26.856536
# 9             17.411028             78.329645                   17.441028
# 11             0.000000              0.000000                    0.110000
# 14            23.354422             85.332900                   23.414422
# 19            10.000706             76.349516                   10.130706
# 20            26.956431             75.776649                   27.046431
# 30            11.026117             76.944652                   11.156117
# 32            21.157735             72.768778                   21.177735
# 33            13.022394             80.242439                   13.052394
# 36            26.914142             75.805704                   26.964142
#
#     Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 3                     75.927333  02-04-2022       17:15             17:20
# 9                     78.359645  05-04-2022       20:45             20:55
# 11                     0.110000  08-03-2022       23:40             23:50
# 14                    85.392900  17-03-2022       21:30             21:40
# 19                    76.479516  16-02-2022       21:20             21:25
# 20                    75.866649  04-03-2022       22:10             22:20
# 30                    77.074652  08-03-2022       23:60             24:15
# 32                    72.788778  05-03-2022        8:25              8:30
# 33                    80.272439  07-03-2022       19:15             19:20
# 36                    75.855704  01-04-2022       18:35             18:40
#
#    Weather Road_traffic_density  Vehicle_condition Type_of_order  \
# 3      Fog               Medium                  1          Meal
# 9      Fog                  Jam                  1          Meal
# 11   Windy                  Low                  1        Drinks
# 14     Fog                  Jam                  1          Meal
# 19  Stormy                  Jam                  1        Drinks
# 20   Sunny                  Low                  1          Meal
# 30   Windy                  Low                  1        Buffet
# 32   Sunny                  Low                  1          Meal
# 33  Stormy                  Jam                  1          Meal
# 36     Fog               Medium                  1          Meal
#
#    Type_of_vehicle  multiple_deliveries Festival           City   Name:
# 3          scooter                  1.0       No  Metropolitian  object
# 9       motorcycle                  0.0       No  Metropolitian  object
# 11         scooter                  NaN       No          Urban  object
# 14         scooter                  0.0       No  Metropolitian  object
# 19         scooter                  1.0       No          Urban  object
# 20         scooter                  1.0       No  Metropolitian  object
# 30         scooter                  0.0       No  Metropolitian  object
# 32         scooter                  1.0       No          Urban  object
# 33         scooter                  0.0       No  Metropolitian  object
# 36      motorcycle                  1.0       No          Urban  object

# %% [markdown]
# # 14. Menampilkan Delivery_person_ID,Type_of_order, Weather dan Type_of_vehicle

# %%
cleaned_data = cleaned_df[['Delivery_person_ID', 'Type_of_order', 'Weather', 'Type_of_vehicle']]
print(cleaned_data)
# Out:
#       Delivery_person_ID Type_of_order     Weather   Type_of_vehicle
# 0        COIMBRES13DEL01        Drinks         NaN  electric_scooter
# 1         BANGRES15DEL01         Snack       Windy        motorcycle
# 2          JAPRES09DEL03        Drinks      Stormy        motorcycle
# 3          JAPRES07DEL03          Meal         Fog           scooter
# 4         CHENRES19DEL01        Drinks       Sunny           scooter
# ...                  ...           ...         ...               ...
# 11394      JAPRES01DEL01         Snack       Sunny           scooter
# 11395      JAPRES11DEL01        Drinks  Sandstorms           scooter
# 11396      SURRES11DEL03        Drinks         NaN           scooter
# 11397      VADRES03DEL02          Meal  Sandstorms        motorcycle
# 11398     CHENRES07DEL02        Drinks       Windy        motorcycle
#
# [11399 rows x 4 columns]

# %% [markdown]
# # 15. menghitung jumlah cleaned Vehicle condition yang ada

# %%
jumlah_cleaned_Vehicle_condition = cleaned_df['Vehicle_condition'].value_counts()

print(jumlah_cleaned_Vehicle_condition)
# Out:
# 2    3821
# 1    3734
# 0    3717
# 3     127
# Name: Vehicle_condition, dtype: int64

# %% [markdown]
# # 16.menampilkan jumlah kondisi kendaraan terbanyak dan tipe kendaraan

# %%
cleaned_Vehicle_condition = cleaned.loc[cleaned['Vehicle_condition'].idxmax()]

print("Kondisi kendaraan terbanyak")
print("Tipe kendaraan:",cleaned_Vehicle_condition ['Type_of_vehicle'])
print("Kondisi kendaraan:",cleaned_Vehicle_condition['Vehicle_condition'])
# Out:
# Kondisi kendaraan terbanyak
# Tipe kendaraan: electric_scooter
# Kondisi kendaraan: 3

# %% [markdown]
# # 17.menampilkan jumlah kondisi kendaraan paling sedikit dan tipe kendaraan

# %%
cleaned_Vehicle_condition = cleaned.loc[cleaned['Vehicle_condition'].idxmin()]

print("Kondisi kendaraan terkecil")
print("Tipe kendaraan:",cleaned_Vehicle_condition ['Type_of_vehicle'])
print("Kondisi kendaraan:",cleaned_Vehicle_condition['Vehicle_condition'])
# Out:
# Kondisi kendaraan terkecil
# Tipe kendaraan: motorcycle
# Kondisi kendaraan: 0

# %% [markdown]
# # 18. menampilkan Type_of_order dengan Vehicle_condition terbanyak

# %%
Type_of_order_Vehicle_condition = cleaned.groupby('Type_of_order')[['Vehicle_condition']].sum()
Sorted_Vehicle_condition = Type_of_order_Vehicle_condition.sort_values('Vehicle_condition', ascending = False) [:4]
Sorted_Vehicle_condition
# Out:
#                Vehicle_condition
# Type_of_order
# Drinks                      3012
# Buffet                      2975
# Meal                        2915
# Snack                       2855

# %% [markdown]
# # 19. Memvisualisasikan jumlah dan 'tipe order' dari dataset

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Type_of_order', data=cleaned)
plt.xlabel('tipe order')
plt.ylabel('Count')
plt.title('Cleaned Plot')
plt.show()

# %% [markdown]
# # 20.  menghitung jumlah Type_of_vehicle dengan tipe tertentu

# %%
len (cleaned[cleaned['Type_of_vehicle'].str.contains('scooter')])
# Out:
# 4767

# %% [markdown]
# # 21. menampilkan 2 Vehicle_condition dengan Delivery_person_ID, Ty peof vehicle dan Vehicle_condition

# %%
cleaned.nlargest(2, 'Vehicle_condition') [['Delivery_person_ID', 'Type_of_vehicle', 'Vehicle_condition']]
# Out:
#    Delivery_person_ID   Type_of_vehicle  Vehicle_condition
# 0     COIMBRES13DEL01  electric_scooter                  3
# 57      AGRRES03DEL03  electric_scooter                  3

# %% [markdown]
# # 22. mengklasifikasikan data cleaned berdasarkan Delivery_person_Ratings[Excellent, good, dan Average]

# %%
def Delivery_person_Ratings(Delivery_person_Ratings):
  if Delivery_person_Ratings>=4.9:
    return "Excellent"
  elif Delivery_person_Ratings>=4.5:
    return "Good"
  else:
    return "Average"

cleaned['rate']=cleaned['Delivery_person_Ratings'].apply(Delivery_person_Ratings)
cleaned.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                  NaN                      NaN
# 1  0x3474     BANGRES15DEL01                 28.0                      4.6
# 2  0x9420      JAPRES09DEL03                 23.0                      4.5
# 3  0x72ee      JAPRES07DEL03                 21.0                      4.8
# 4  0xa759     CHENRES19DEL01                 31.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
# 1            12.975377             77.696664                   13.085377
# 2            26.911378             75.789034                   27.001378
# 3            26.766536             75.837333                   26.856536
# 4            12.986047             80.218114                   13.096047
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ... Weather  \
# 0                    77.016494  30-03-2022         NaN  ...     NaN
# 1                    77.806664  29-03-2022       20:30  ...   Windy
# 2                    75.879034  10-03-2022       19:35  ...  Stormy
# 3                    75.927333  02-04-2022       17:15  ...     Fog
# 4                    80.328114  27-03-2022       18:25  ...   Sunny
#
#   Road_traffic_density Vehicle_condition  Type_of_order   Type_of_vehicle  \
# 0                  NaN                 3         Drinks  electric_scooter
# 1                  Jam                 0          Snack        motorcycle
# 2                  Jam                 0         Drinks        motorcycle
# 3               Medium                 1           Meal           scooter
# 4               Medium                 2         Drinks           scooter
#
#   multiple_deliveries  Festival           City   Name:     rate
# 0                 1.0        No  Metropolitian  object  Average
# 1                 1.0        No  Metropolitian  object     Good
# 2                 1.0        No  Metropolitian  object     Good
# 3                 1.0        No  Metropolitian  object     Good
# 4                 1.0        No  Metropolitian  object     Good
#
# [5 rows x 21 columns]

# %% [markdown]
# # 23. menampilkan 15 data dengan Delivery person Ratings tertinggi

# %%
cleaned.nlargest(15, 'Delivery_person_Ratings') [['Delivery_person_ID', 'Type_of_vehicle', 'Delivery_person_Ratings']]
# Out:
#       Delivery_person_ID   Type_of_vehicle  Delivery_person_Ratings
# 1069       KNPRES14DEL02           scooter                      6.0
# 1391       JAPRES01DEL02           bicycle                      6.0
# 1974      PUNERES15DEL02           bicycle                      6.0
# 2024      BANGRES08DEL02  electric_scooter                      6.0
# 2995       KOCRES07DEL02        motorcycle                      6.0
# 3876       SURRES14DEL02        motorcycle                      6.0
# 5649       AGRRES04DEL03           bicycle                      6.0
# 6528       MUMRES18DEL01           bicycle                      6.0
# 8424       VADRES17DEL02  electric_scooter                      6.0
# 10748     BANGRES19DEL01        motorcycle                      6.0
# 24       COIMBRES05DEL02           scooter                      5.0
# 30       COIMBRES17DEL02           scooter                      5.0
# 44        CHENRES09DEL03        motorcycle                      5.0
# 50        CHENRES03DEL01        motorcycle                      5.0
# 71         MUMRES09DEL01        motorcycle                      5.0

# %% [markdown]
# # 24. menampilkan 3 Delivery_person_Age tertinggi

# %%
cleaned.nlargest(3, 'Delivery_person_Age') [[ 'Type_of_vehicle', 'Delivery_person_Age']]
# Out:
#      Type_of_vehicle  Delivery_person_Age
# 1069         scooter                 50.0
# 1391         bicycle                 50.0
# 1974         bicycle                 50.0

# %% [markdown]
# # 25.Memvisualisasikan Delivery_person_Age dengan rata-rata Delivery person Ratings tertinggi

# %%
plt.figure(figsize=(8,5))
sns.barplot (x='Delivery_person_Ratings', y='Delivery_person_Age', data=cleaned)
plt.title("Delivery person Ratings tertinggi")
plt.show()

# %% [markdown]
# # 26. menampilkan Delivery_person_Ratings yang lebih dari 4.6

# %%
cleaned[cleaned['Delivery_person_Ratings']>=4.6] [['Type_of_vehicle', 'Delivery_person_Ratings'] ]
# Out:
#       Type_of_vehicle  Delivery_person_Ratings
# 1          motorcycle                      4.6
# 3             scooter                      4.8
# 4             scooter                      4.6
# 5          motorcycle                      4.7
# 6             scooter                      4.8
# ...               ...                      ...
# 11393         scooter                      4.7
# 11394         scooter                      4.6
# 11395         scooter                      4.9
# 11397      motorcycle                      4.7
# 11398      motorcycle                      5.0
#
# [8048 rows x 2 columns]

# %% [markdown]
# # 27. Menghitung jumlah Delivery person Ratings yang ada

# %%
jumlah_Delivery_person_Ratings = cleaned_df['Delivery_person_Ratings'].value_counts()

print(jumlah_Delivery_person_Ratings)
# Out:
# 4.9    1863
# 4.8    1790
# 4.7    1723
# 4.6    1663
# 5.0     999
# 4.5     843
# 4.2     351
# 4.3     341
# 4.4     326
# 4.1     311
# 4.0     295
# 3.5      66
# 3.9      62
# 3.7      59
# 3.8      51
# 3.6      51
# 3.3      13
# 3.4      12
# 2.6      12
# 6.0      10
# 1.0       9
# 2.5       8
# 3.1       8
# 2.7       7
# 3.2       7
# 2.9       7
# 2.8       3
# 3.0       2
# Name: Delivery_person_Ratings, dtype: int64

# %% [markdown]
# # 28. memvisualisasikan jumlah Weather

# %%
plt.figure(figsize=(10,5))
sns.countplot (x='Weather',data=cleaned)
# Out:
# <Axes: xlabel='Weather', ylabel='count'>

# %% [markdown]
# # 29. Menampilkan Type of order dan Order Date

# %%
cleaned_Order_Date_data = cleaned_df[['Type_of_order', 'Order_Date']]
print(cleaned_Order_Date_data)
# Out:
#       Type_of_order  Order_Date
# 0            Drinks  30-03-2022
# 1             Snack  29-03-2022
# 2            Drinks  10-03-2022
# 3              Meal  02-04-2022
# 4            Drinks  27-03-2022
# ...             ...         ...
# 11394         Snack  27-03-2022
# 11395        Drinks  11-03-2022
# 11396        Drinks  11-03-2022
# 11397          Meal  06-03-2022
# 11398        Drinks  24-03-2022
#
# [11399 rows x 2 columns]
